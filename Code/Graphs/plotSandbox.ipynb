# %%
"""
Purpose: Interactive notebook for generating and refining visualizations comparing model performances 
         across different feature types, focusing on box plots and violin plots for distribution analysis.

Key Visualizations:
    - Simple Features: Box plots with optimal single feature markers
    - Echonest Features: Violin plots with both optimal single and combined feature markers
    - Enhanced legend placement and grid styling
"""

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Single Feature Comparisons

# %%
# Define the data for Naive Bayes, SGD, and KNN models
naive_bayes_simple = [0.43, 0.45, 0.44, 0.25]
naive_bayes_echonest = [0.47, 0.55, 0.48, 0.47, 0.47, 0.5, 0.47, 0.47]

sgd_simple = [0.44, 0.44, 0.44, 0.5]
sgd_echonest = [0.47, 0.48, 0.48, 0.47, 0.47, 0.49, 0.47, 0.47]

knn_simple = [0.46, 0.46, 0.46, 0.44]
knn_echonest = [0.46, 0.55, 0.48, 0.47, 0.47, 0.51, 0.52, 0.47]

# Create a DataFrame to combine the data
data = {
    'Model': ['Naive Bayes'] * (len(naive_bayes_simple) + len(naive_bayes_echonest)) +
             ['SGD'] * (len(sgd_simple) + len(sgd_echonest)) +
             ['KNN'] * (len(knn_simple) + len(knn_echonest)),
    'Features': ['Simple'] * len(naive_bayes_simple) + ['Echonest'] * len(naive_bayes_echonest) +
                ['Simple'] * len(sgd_simple) + ['Echonest'] * len(sgd_echonest) +
                ['Simple'] * len(knn_simple) + ['Echonest'] * len(knn_echonest),
    'Accuracy': naive_bayes_simple + naive_bayes_echonest +
                sgd_simple + sgd_echonest +
                knn_simple + knn_echonest
}
df = pd.DataFrame(data)

# Define custom colors for each feature
colors = {"Simple": "#86BBD8", "Echonest": "#FED4E7"}


# Create the box plot using Seaborn
plt.figure(figsize=(12, 8))
sns.boxplot(x='Model', y='Accuracy', hue='Features', data=df, palette=colors, width=0.7)
plt.title('Comparison of Model Accuracy by Single Feature Models')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.legend(title='Features')
plt.grid(axis='y', which='major', linestyle='-', linewidth='0.5', color='black')
plt.minorticks_on()
plt.grid(axis='y', which='minor', linestyle=':', linewidth='0.5', color='gray')

plt.show()

# %% [markdown]
# ## Feature Combinations

# %% [markdown]
# ### Simple Features

# %%
# NOTE - Maybe try to put these on the same axes range as the individual features one? 

# Define the data for NB, SGD, and KNN models with linear combinations of features
nb_accuracies = [0.44, 0.44, 0.45, 0.44]
sgd_accuracies = [0.44, 0.52, 0.44, 0.51, 0.44, 0.5, 0.44, 0.51]
knn_accuracies = [0.49, 0.48, 0.48, 0.47, 0.49]

# Create a DataFrame to combine the data
data = {
    'Model': ['Naive Bayes'] * len(nb_accuracies) +
             ['SGD'] * len(sgd_accuracies) +
             ['KNN'] * len(knn_accuracies),
    'Accuracy': nb_accuracies + sgd_accuracies + knn_accuracies
}
df_linear_combinations = pd.DataFrame(data)

highest_single_feature = {
    'Naive Bayes': 0.45,
    'SGD': 0.5,
    'KNN': 0.46
}



# Create the box plot using Seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(x='Model', y='Accuracy', data=df_linear_combinations, color="#86BBD8")
plt.title('Model Performance with Linear Combination of Simple Features')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.grid(axis='y', which='major', linestyle='-', linewidth='0.5', color='gray')
plt.minorticks_on()
plt.grid(axis='y', which='minor', linestyle=':', linewidth='0.5', color='gray')

for model, accuracy in highest_single_feature.items():
    plt.scatter(model, accuracy, color='#1E475c', marker='o',zorder=3)


# Create a proxy artist for the legend
red_cross = plt.Line2D([0], [0], marker='o', color='w', label='Optimal Single Simple Feature Model', markerfacecolor='#1E475C', markersize=10)

plt.legend(handles=[red_cross])

plt.show()

# %% [markdown]
# ### Echonest Features

# %%
# Move legend so it doesn't obscure

# Define the data for NB, SGD, and KNN models with linear combinations of features
nb_accuracies = [
    0.57, 0.49, 0.47, 0.48, 0.51, 0.47, 0.48, 0.57, 0.57, 0.55, 0.57, 0.55, 0.55, 0.49, 0.48, 0.51, 0.48, 0.48, 0.47, 0.52, 0.47, 0.47, 0.5, 0.47, 0.47, 0.5, 0.5, 0.47, 0.58, 0.58,
    0.57, 0.58, 0.57, 0.57, 0.49, 0.49, 0.52, 0.48, 0.49, 0.46, 0.53, 0.5, 0.48, 0.51, 0.47, 0.48, 0.51, 0.51, 0.48, 0.58, 0.56, 0.58, 0.57, 0.56, 0.57, 0.59,
    0.57, 0.57, 0.57, 0.56, 0.55, 0.56, 0.57, 0.55, 0.48, 0.54, 0.49, 0.48, 0.51, 0.48, 0.48, 0.51, 0.51, 0.48, 0.52, 0.47, 0.47, 0.52, 0.53, 0.47, 0.5, 0.5, 0.48, 0.51,
    0.6, 0.58, 0.59, 0.58, 0.58, 0.59, 0.61, 0.59, 0.58, 0.58, 0.58, 0.57, 0.58, 0.58, 0.57, 0.49, 0.56, 0.49, 0.5, 0.52, 0.49, 0.49, 0.52, 0.53, 0.5, 0.54, 0.5, 0.49,
    0.54, 0.56, 0.5, 0.52, 0.52, 0.49, 0.52, 0.59, 0.61, 0.59, 0.57, 0.58, 0.57, 0.55, 0.58, 0.58, 0.56, 0.59, 0.57, 0.57, 0.59, 0.59, 0.57, 0.56, 0.57, 0.55, 0.57, 0.53,
    0.49, 0.49, 0.54, 0.54, 0.49, 0.51, 0.51, 0.48, 0.51, 0.52, 0.53, 0.47, 0.52, 0.5, 0.6, 0.63, 0.6, 0.6, 0.59, 0.58, 0.58, 0.59, 0.59, 0.58, 0.62, 0.59, 0.58, 0.62, 0.61,
    0.59, 0.59, 0.59, 0.59, 0.59, 0.55, 0.49, 0.49, 0.55, 0.57, 0.51, 0.52, 0.53, 0.49, 0.53, 0.55, 0.56, 0.5, 0.55, 0.53, 0.61, 0.59, 0.57, 0.61, 0.6, 0.58, 0.58, 0.58, 0.57,
    0.57, 0.59, 0.59, 0.57, 0.59, 0.57, 0.54, 0.53, 0.49, 0.54, 0.51, 0.53, 0.63, 0.6, 0.6, 0.63, 0.62, 0.6, 0.59, 0.59, 0.58, 0.59, 0.62, 0.62, 0.6, 0.62, 0.6, 0.55, 0.56,
    0.5, 0.56, 0.53, 0.56, 0.61, 0.6, 0.58, 0.6, 0.58, 0.59, 0.54, 0.63, 0.62, 0.6, 0.62, 0.59, 0.63, 0.56, 0.6, 0.62
]

sgd_accuracies = [
    0.55, 0.48, 0.47, 0.47, 0.5, 0.47, 0.47, 0.56, 0.58, 0.45, 0.51, 0.55, 0.55, 0.48, 0.48, 0.5, 0.48, 0.47, 0.47, 0.49, 0.47, 0.45, 0.5, 0.47, 0.47, 0.5, 0.49, 0.47, 0.55, 0.58,
    0.55, 0.56, 0.55, 0.58, 0.5, 0.49, 0.52, 0.47, 0.47, 0.47, 0.52, 0.47, 0.47, 0.5, 0.47, 0.47, 0.5, 0.5, 0.47, 0.55, 0.56, 0.56, 0.56, 0.57, 0.56, 0.59, 0.56, 0.58, 0.53, 0.55, 0.56,
    0.6, 0.61, 0.6, 0.61, 0.6, 0.63, 0.61, 0.6, 0.6, 0.59, 0.58, 0.61, 0.6, 0.6, 0.58, 0.59, 0.59, 0.61, 0.56, 0.49, 0.5, 0.56, 0.56, 0.5, 0.54, 0.54, 0.5, 0.55, 0.55, 0.55, 0.48, 0.54,
    0.54, 0.62, 0.64, 0.63, 0.63, 0.62, 0.6, 0.61, 0.63, 0.63, 0.62, 0.62, 0.62, 0.6, 0.63, 0.62, 0.62, 0.61, 0.6, 0.6, 0.62, 0.57, 0.54, 0.54, 0.57, 0.58, 0.54, 0.55, 0.56, 0.52, 0.58,
    0.55, 0.55, 0.51, 0.55, 0.55, 0.62, 0.61, 0.61, 0.63, 0.63, 0.62, 0.61, 0.63, 0.6, 0.63, 0.6, 0.6, 0.59, 0.62, 0.61, 0.55, 0.55, 0.5, 0.56, 0.54, 0.53, 0.64, 0.63, 0.62, 0.65, 0.66,
    0.63, 0.62, 0.64, 0.62, 0.63, 0.63, 0.63, 0.62, 0.62, 0.62, 0.61, 0.6, 0.6, 0.62, 0.57, 0.54, 0.54, 0.57, 0.56, 0.54, 0.55, 0.56, 0.52, 0.58, 0.55, 0.55, 0.51, 0.55, 0.55, 0.62, 0.61,
    0.61, 0.63, 0.63, 0.62, 0.61, 0.63, 0.6, 0.63, 0.6, 0.6, 0.59, 0.62, 0.61, 0.55, 0.55, 0.5, 0.56, 0.54, 0.53, 0.64, 0.63, 0.62, 0.65, 0.66, 0.63, 0.62, 0.64, 0.62, 0.63, 0.63, 0.63, 0.62,
    0.62, 0.62, 0.62, 0.63, 0.56, 0.57, 0.54, 0.57, 0.56, 0.54, 0.62, 0.63, 0.62, 0.64, 0.63, 0.61, 0.55, 0.65, 0.64, 0.62, 0.64, 0.64, 0.63, 0.56, 0.65, 0.64
]

# Create a DataFrame to combine the data
data = {
    'Model': ['Naive Bayes'] * len(nb_accuracies) +
             ['SGD'] * len(sgd_accuracies) +
             ['KNN'] * len(knn_accuracies),
    'Accuracy': nb_accuracies + sgd_accuracies + knn_accuracies
}
df_linear_combinations = pd.DataFrame(data)

# Create the box plot using Seaborn
plt.figure(figsize=(10, 6))
sns.violinplot(x='Model', y='Accuracy', data=df_linear_combinations, color="#FED4E7")



plt.title('Model Performance with Linear Combination of Echonest Features')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.grid(axis='y', which='major', linestyle='-', linewidth='0.5', color='gray')
plt.minorticks_on()
plt.grid(axis='y', which='minor', linestyle=':', linewidth='0.5', color='gray')


highest_single_feature = {
    'Naive Bayes': 0.55,
    'SGD': 0.49,
    'KNN': 0.55
}

highest_combined_feature = {
    'Naive Bayes': 0.45,
    'SGD': 0.52,
    'KNN': 0.49
}

for model, accuracy in highest_single_feature.items():
    plt.scatter(model, accuracy, color='#B30553', marker='o',zorder=3)

for model, accuracy in highest_combined_feature.items():
    plt.scatter(model, accuracy, color='#1e475C', marker='o',zorder=3)


# Create a proxy artist for the legend
red_cross = plt.Line2D([0], [0], marker='o', color='w', label='Optimal Single Echonest Feature', markerfacecolor='#B30553', markersize=10)
green_dot = plt.Line2D([0], [0], marker='o', color='w', label='Optimal Simple Feature Combined', markerfacecolor='#1e475C', markersize=10)

# Add legend with proxy artists
plt.legend(handles=[red_cross, green_dot],loc='upper left')
plt.show()
